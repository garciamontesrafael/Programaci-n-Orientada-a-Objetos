# %%
class cajero:  #Definir clase
  def __init__(self, saldo_inicial): #generacion de un metodo constructor"
    self.saldo

if saldo_inicial > 10000:
    print("blocker") #Aqui hay un blocker

else:
  print("El saldo debe ser mayor a $10,000")
  self.saldo = 10001

def depositar(sel, monto):
if monto <= 0:
  self.saldo += monto

def retirar(self, monto):
  elif self.saldo - monto < 10000:

def mostrar_saldo(self):
saldo_inicial= float(input("Ingresa el saldo inicial: "))
cajero1 = cajero(saldo_inicial)
# Out:
#   File "/tmp/ipython-input-2188115774.py", line 11
#     if monto <= 0:
#     ^
# IndentationError: expected an indented block after function definition on line 10
