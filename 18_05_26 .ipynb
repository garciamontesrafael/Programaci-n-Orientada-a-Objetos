# %%
from logging import exception
b= 0
a= 0
if type(b) is not int:
  raise exception("ERROR de tipo - unicamente se permiten enteros")

elif b == 0:
  print("No se puede dividir entre 0")

else:
  print(a/b)
  print(a/b)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1889480782.py in <cell line: 0>()
#       2 b= 0
#       3 a= 0
# ----> 4 a=int(input("Ingrese su valor a dividir: "))
#       5 b=int(input("Ingrese entre que se dividira: "))
#       6 if type(b) is not int:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
a= float(input("Valor de A: "))
b= float(input("Valor de B: "))
x= -b/a
print("respuesta: ", -b, "/", a, "=", x)
# Out:
# Valor de A: 4
# Valor de B: 8
# respuesta:  -8.0 / 4.0 = -2.0

# %%
a= float(input("Valor de A: "))
b= float(input("Valor de B: "))
if a != 0:
  x=-b/a
  print("Respuesta: ", x)

if a == 0:
  if b !=0:
    print("La operación no se puede realizar...")
  if b ==0:
    print("la operación puede tener varias opciones...")
# Out:
# Valor de A: 100
# Valor de B: 10
# Respuesta:  -0.1

# %%
a =int(input("Inserta un número entero: "))
b =int(input("Inserta otro número entero: "))
if a <= b:
  print(a,"es menor que", b)
elif a > b:
  print(a, "es mayor que", a)
else:
  print(a, "es igual a", b)
# Out:
# Inserta un número entero: 100
# Inserta otro número entero: 100
# 100 es menor que 100

# %%
print("... EJERCICIO ...")
print("TABLA DE MULTIPLICAR")
print("")
print("")

a =int(input("Inserta un número ENTERO: "))
if a % 2 == 0:
  print(a, "es par")
else:
  print(a, "es impar")
b=int(input("Inserta un segundo número ENTERO: "))
if b % 2 == 0:
  print(b, "es par")
else:
  print(b, "es impar")
# Out:
# ... EJERCICIO ...
# TABLA DE MULTIPLICAR
#
#
# Inserta un número ENTERO: 8
# 8 es par
# Inserta un segundo número ENTERO: 9
# 9 es impar

# %%
import random
secreto = random.randint(1,100)
intento = 0

while intento != secreto:
  intento = int(input("Adivina el número: "))
  if intento < secreto:
    print("Muy bajo")
  elif intento > secreto:
    print("Muy alto")

print("¡CORRECTO!")
# Out:
# Adivina el número: 50
# Muy bajo
# Adivina el número: 75
# Muy bajo
# Adivina el número: 85
# Muy alto
# Adivina el número: 80
# Muy alto
# Adivina el número: 78
# Muy alto
